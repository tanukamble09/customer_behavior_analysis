# %%
import pandas as pd

df = pd.read_csv("customer_shopping_behavior.csv")
df.head()
# Out:
#    Customer ID  Age Gender Item Purchased  Category  Purchase Amount (USD)  \
# 0            1   55   Male         Blouse  Clothing                     53
# 1            2   19   Male        Sweater  Clothing                     64
# 2            3   50   Male          Jeans  Clothing                     73
# 3            4   21   Male        Sandals  Footwear                     90
# 4            5   45   Male         Blouse  Clothing                     49
#
#         Location Size      Color  Season  Review Rating Subscription Status  \
# 0       Kentucky    L       Gray  Winter            3.1                 Yes
# 1          Maine    L     Maroon  Winter            3.1                 Yes
# 2  Massachusetts    S     Maroon  Spring            3.1                 Yes
# 3   Rhode Island    M     Maroon  Spring            3.5                 Yes
# 4         Oregon    M  Turquoise  Spring            2.7                 Yes
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3900 entries, 0 to 3899
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   customer_id             3900 non-null   int64
#  1   age                     3900 non-null   int64
#  2   gender                  3900 non-null   str
#  3   item_purchased          3900 non-null   str
#  4   category                3900 non-null   str
#  5   purchase_amount_(usd)   3900 non-null   int64
#  6   location                3900 non-null   str
#  7   size                    3900 non-null   str
#  8   color                   3900 non-null   str
#  9   season                  3900 non-null   str
#  10  review_rating           3863 non-null   float64
#  11  subscription_status     3900 non-null   str
#  12  shipping_type           3900 non-null   str
#  13  discount_applied        3900 non-null   str
#  14  promo_code_used         3900 non-null   str
# ...

# %%
df.describe(include = 'all')
# Out:
#         customer_id          age gender item_purchased  category  \
# count   3900.000000  3900.000000   3900           3900      3900
# unique          NaN          NaN      2             25         4
# top             NaN          NaN   Male         Blouse  Clothing
# freq            NaN          NaN   2652            171      1737
# mean    1950.500000    44.068462    NaN            NaN       NaN
# std     1125.977353    15.207589    NaN            NaN       NaN
# min        1.000000    18.000000    NaN            NaN       NaN
# 25%      975.750000    31.000000    NaN            NaN       NaN
# 50%     1950.500000    44.000000    NaN            NaN       NaN
# 75%     2925.250000    57.000000    NaN            NaN       NaN
# max     3900.000000    70.000000    NaN            NaN       NaN
#
#         purchase_amount_(usd) location  size  color  season  review_rating  \
# count             3900.000000     3900  3900   3900    3900    3863.000000
# ...

# %%
df.isnull().sum()
# Out:
# customer_id                0
# age                        0
# gender                     0
# item_purchased             0
# category                   0
# purchase_amount_(usd)      0
# location                   0
# size                       0
# color                      0
# season                     0
# review_rating             37
# subscription_status        0
# shipping_type              0
# discount_applied           0
# promo_code_used            0
# previous_purchases         0
# payment_method             0
# frequency_of_purchases     0
# dtype: int64

# %%
df['Review Rating'] = df.groupby('Category')['Review Rating'].transform(lambda x:x.fillna(x.median()))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 df['Review Rating'] = df.groupby('Category')['Review Rating'].transform(lambda x:x.fillna(x.median()))
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\util\_decorators.py:336, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     330 if len(args) > num_allow_args:
#     331     warnings.warn(
#     332         msg.format(arguments=_format_argument_list(allow_args)),
#     333         klass,
#     334         stacklevel=find_stack_level(),
#     335     )
# --> 336 return func(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\frame.py:10833, in DataFrame.groupby(self, by, level, as_index, sort, group_keys, observed, dropna)
#   10829
#   10830         if level is None and by is None:
# ...

# %%
df.isnull().sum()
# Out:
# customer_id                0
# age                        0
# gender                     0
# item_purchased             0
# category                   0
# purchase_amount_(usd)      0
# location                   0
# size                       0
# color                      0
# season                     0
# review_rating             37
# subscription_status        0
# shipping_type              0
# discount_applied           0
# promo_code_used            0
# previous_purchases         0
# payment_method             0
# frequency_of_purchases     0
# dtype: int64

# %%
df.columns = df.columns.str.lower()
df.columns = df.columns.str.replace(' ','_')
df =df.rename(columns={'purchase_amount_(usd)':'purchase_amount'})

# %%
df.columns
# Out:
# Index(['customer_id', 'age', 'gender', 'item_purchased', 'category',
#        'purchase_amount', 'location', 'size', 'color', 'season',
#        'review_rating', 'subscription_status', 'shipping_type',
#        'discount_applied', 'promo_code_used', 'previous_purchases',
#        'payment_method', 'frequency_of_purchases'],
#       dtype='str')

# %%
#create a age group 
labels = ['Young Adult','Adult','Middel-aged','Senior']
df['age_group'] =pd.qcut(df['age'],q=4,labels =labels)

# %%
df[['age','age_group']].head(10)
# Out:
#    age    age_group
# 0   55  Middel-aged
# 1   19  Young Adult
# 2   50  Middel-aged
# 3   21  Young Adult
# 4   45  Middel-aged
# 5   46  Middel-aged
# 6   63       Senior
# 7   27  Young Adult
# 8   26  Young Adult
# 9   57  Middel-aged

# %%
#create column purcahse_frequency_days
frequency_mapping = {'Fortnightly':14,
                     'Weekly':7,
                     'Monthly':30,
                     'Quarterly':90,
                     'Bi-Weekly':14,
                     'Annually':365,
                     'Every 3 Months':90}
df['purchase_frequency_days'] =df['frequency_of_purchases'].map(frequency_mapping)

# %%
df[['purchase_frequency_days','frequency_of_purchases']].head(10)
# Out:
#    purchase_frequency_days frequency_of_purchases
# 0                       14            Fortnightly
# 1                       14            Fortnightly
# 2                        7                 Weekly
# 3                        7                 Weekly
# 4                      365               Annually
# 5                        7                 Weekly
# 6                       90              Quarterly
# 7                        7                 Weekly
# 8                      365               Annually
# 9                       90              Quarterly

# %%
df[['discount_applied','promo_code_used']].head(10)
# Out:
#   discount_applied promo_code_used
# 0              Yes             Yes
# 1              Yes             Yes
# 2              Yes             Yes
# 3              Yes             Yes
# 4              Yes             Yes
# 5              Yes             Yes
# 6              Yes             Yes
# 7              Yes             Yes
# 8              Yes             Yes
# 9              Yes             Yes

# %%
(df['discount_applied']==df['promo_code_used']).all()
# Out:
# np.True_

# %%
df.columns
# Out:
# Index(['customer_id', 'age', 'gender', 'item_purchased', 'category',
#        'purchase_amount', 'location', 'size', 'color', 'season',
#        'review_rating', 'subscription_status', 'shipping_type',
#        'discount_applied', 'promo_code_used', 'previous_purchases',
#        'payment_method', 'frequency_of_purchases', 'age_group',
#        'purchase_frequency_days'],
#       dtype='str')

# %%
df. columns
# Out:
# Index(['customer_id', 'age', 'gender', 'item_purchased', 'category',
#        'purchase_amount', 'location', 'size', 'color', 'season',
#        'review_rating', 'subscription_status', 'shipping_type',
#        'discount_applied', 'promo_code_used', 'previous_purchases',
#        'payment_method', 'frequency_of_purchases', 'age_group',
#        'purchase_frequency_days'],
#       dtype='str')

# %%
for col in df.columns:
    print(repr(col))
# Out:
# 'customer_id'
# 'age'
# 'gender'
# 'item_purchased'
# 'category'
# 'purchase_amount'
# 'location'
# 'size'
# 'color'
# 'season'
# 'review_rating'
# 'subscription_status'
# 'shipping_type'
# 'discount_applied'
# 'promo_code_used'
# 'previous_purchases'
# 'payment_method'
# 'frequency_of_purchases'
# 'age_group'
# 'purchase_frequency_days'

# %%
df.columns = df.columns.str.strip().str.lower()

df.to_sql(
    "customer_behavior",
    engine,
    if_exists="replace",   # Replaces the old table
    index=False
)

print("Table updated successfully!")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 5
#       1 df.columns = df.columns.str.strip().str.lower()
#       2
#       3 df.to_sql(
#       4     "customer_behavior",
# ----> 5     engine,
#       6     if_exists="replace",   # Replaces the old table
#       7     index=False
#       8 )
#
# NameError: name 'engine' is not defined

# %%
print("promo_code_used" in df.columns)
# Out:
# True

# %%
import sys
print(sys.version)
# Out:
# 3.13.7 (tags/v3.13.7:bcee1c3, Aug 14 2025, 14:15:11) [MSC v.1944 64 bit (AMD64)]

# %%
# !python -m pip install psycopg[binary] sqlalchemy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# [notice] A new release of pip is available: 25.2 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from sqlalchemy import create_engine
from urllib.parse import quote_plus

username = "postgres"
password = quote_plus("Tanu@123")   # Your PostgreSQL password
host = "localhost"
port = "5432"
database = "postgres"

engine = create_engine(
    f"postgresql+psycopg://{username}:{password}@{host}:{port}/{database}"
)

conn = engine.connect()

print("✅ Connected Successfully!")

# %%
import pandas as pd

df = pd.read_sql("SELECT version();", conn)
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 3
#       1 import pandas as pd
#       2
# ----> 3 df = pd.read_sql("SELECT version();", conn)
#       4 df
#
# NameError: name 'conn' is not defined

# %%
pd.read_sql("""
SELECT datname
FROM pg_database;
""", conn)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 4
#       1 pd.read_sql("""
#       2 SELECT datname
#       3 FROM pg_database;
# ----> 4 """, conn)
#
# NameError: name 'conn' is not defined

# %%
from sqlalchemy import create_engine
from urllib.parse import quote_plus

username = "postgres"
password = quote_plus("Tanu@123")
host = "localhost"
port = "5432"
database = "customer_behavior"   # Change this

engine = create_engine(
    f"postgresql+psycopg://{username}:{password}@{host}:{port}/{database}"
)

conn = engine.connect()
print("✅ Connected to customer_behavior")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python313\site-packages\sqlalchemy\engine\base.py:144, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     143 try:
# --> 144     self._dbapi_connection = engine.raw_connection()
#     145 except dialect.loaded_dbapi.Error as err:
#
# File ~\AppData\Roaming\Python\Python313\site-packages\sqlalchemy\engine\base.py:3319, in Engine.raw_connection(self)
#    3298 """Return a "raw" DBAPI connection from the connection pool.
#    3299
#    3300 The returned object is a proxied version of the DBAPI
#    (...)   3317
#    3318 """
# -> 3319 return self.pool.connect()
#
# File ~\AppData\Roaming\Python\Python313\site-packages\sqlalchemy\pool\base.py:448, in Pool.connect(self)
#     441 """Return a DBAPI connection from the pool.
#     442
# ...

# %%
import pandas as pd

pd.read_sql("""
SELECT table_name
FROM information_schema.tables
WHERE table_schema='public';
""", conn)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 7
#       3 pd.read_sql("""
#       4 SELECT table_name
#       5 FROM information_schema.tables
#       6 WHERE table_schema='public';
# ----> 7 """, conn)
#
# NameError: name 'conn' is not defined

# %%
pd.read_sql("""
SELECT schemaname, tablename
FROM pg_tables;
""", conn)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 4
#       1 pd.read_sql("""
#       2 SELECT schemaname, tablename
#       3 FROM pg_tables;
# ----> 4 """, conn)
#
# NameError: name 'conn' is not defined

# %%
pd.read_sql("SELECT current_database();", conn)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 pd.read_sql("SELECT current_database();", conn)
#
# NameError: name 'conn' is not defined

# %%
from sqlalchemy import text

with engine.begin() as connection:
    connection.execute(text("ALTER USER postgres WITH PASSWORD 'Tanu@123';"))

print("Password reset successfully")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python313\site-packages\sqlalchemy\engine\base.py:144, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     143 try:
# --> 144     self._dbapi_connection = engine.raw_connection()
#     145 except dialect.loaded_dbapi.Error as err:
#
# File ~\AppData\Roaming\Python\Python313\site-packages\sqlalchemy\engine\base.py:3319, in Engine.raw_connection(self)
#    3298 """Return a "raw" DBAPI connection from the connection pool.
#    3299
#    3300 The returned object is a proxied version of the DBAPI
#    (...)   3317
#    3318 """
# -> 3319 return self.pool.connect()
#
# File ~\AppData\Roaming\Python\Python313\site-packages\sqlalchemy\pool\base.py:448, in Pool.connect(self)
#     441 """Return a DBAPI connection from the pool.
#     442
# ...

# %%
from sqlalchemy import text

with engine.begin() as connection:
    connection.execute(text("ALTER USER postgres WITH PASSWORD 'Tanu123';"))

print("Password changed to Tanu123")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python313\site-packages\sqlalchemy\engine\base.py:144, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     143 try:
# --> 144     self._dbapi_connection = engine.raw_connection()
#     145 except dialect.loaded_dbapi.Error as err:
#
# File ~\AppData\Roaming\Python\Python313\site-packages\sqlalchemy\engine\base.py:3319, in Engine.raw_connection(self)
#    3298 """Return a "raw" DBAPI connection from the connection pool.
#    3299
#    3300 The returned object is a proxied version of the DBAPI
#    (...)   3317
#    3318 """
# -> 3319 return self.pool.connect()
#
# File ~\AppData\Roaming\Python\Python313\site-packages\sqlalchemy\pool\base.py:448, in Pool.connect(self)
#     441 """Return a DBAPI connection from the pool.
#     442
# ...

# %%
pd.read_sql("SELECT inet_server_addr(), inet_server_port(), current_user, current_database();", conn)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 pd.read_sql("SELECT inet_server_addr(), inet_server_port(), current_user, current_database();", conn)
#
# NameError: name 'conn' is not defined

# %%
pd.read_sql("""
SELECT table_name
FROM information_schema.tables
WHERE table_schema='public';
""", conn)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[35], line 5
#       1 pd.read_sql("""
#       2 SELECT table_name
#       3 FROM information_schema.tables
#       4 WHERE table_schema='public';
# ----> 5 """, conn)
#
# NameError: name 'conn' is not defined

# %%
from sqlalchemy import text

with engine.begin() as connection:
    connection.execute(text("""
    INSERT INTO customers VALUES
    (1, 'Tanu', 23, 'Nagpur'),
    (2, 'Amit', 25, 'Pune'),
    (3, 'Priya', 22, 'Mumbai');
    """))

print("Data inserted")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python313\site-packages\sqlalchemy\engine\base.py:144, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     143 try:
# --> 144     self._dbapi_connection = engine.raw_connection()
#     145 except dialect.loaded_dbapi.Error as err:
#
# File ~\AppData\Roaming\Python\Python313\site-packages\sqlalchemy\engine\base.py:3319, in Engine.raw_connection(self)
#    3298 """Return a "raw" DBAPI connection from the connection pool.
#    3299
#    3300 The returned object is a proxied version of the DBAPI
#    (...)   3317
#    3318 """
# -> 3319 return self.pool.connect()
#
# File ~\AppData\Roaming\Python\Python313\site-packages\sqlalchemy\pool\base.py:448, in Pool.connect(self)
#     441 """Return a DBAPI connection from the pool.
#     442
# ...

# %%
pd.read_sql("SELECT * FROM customers;", conn)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 pd.read_sql("SELECT * FROM customers;", conn)
#
# NameError: name 'conn' is not defined

# %%
import os

downloads = r"C:\Users\Tanu Kailash Kamble\Downloads"

for file in os.listdir(downloads):
    if file.endswith(".csv"):
        print(file)
# Out:
# airline_route_profitability_1200_rows.csv
# amazon.csv
# Claims.csv
# customer_shopping_behavior.csv
# data_cleaning_practice_dataset.csv
# Date.csv
# finance sql.csv
# googleplaystore (1).csv
# googleplaystore (2).csv
# googleplaystore.csv
# Hospital_Data.csv
# indian_roads_dataset.csv
# Item.csv
# Location.csv
# messy_dataset_5000_rows.csv
# Payment.csv
# Payments.csv
# perishable_goods_management.csv
# pizza_sales.csv
# Policies.csv
# Sales.csv
# samplesuperstore (1).csv
# samplesuperstore.csv
# sql file.csv
# student.csv
# test.csv

# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\Tanu Kailash Kamble\Downloads\customer_shopping_behavior.csv")
df.head()
# Out:
#    Customer ID  Age Gender Item Purchased  Category  Purchase Amount (USD)  \
# 0            1   55   Male         Blouse  Clothing                     53
# 1            2   19   Male        Sweater  Clothing                     64
# 2            3   50   Male          Jeans  Clothing                     73
# 3            4   21   Male        Sandals  Footwear                     90
# 4            5   45   Male         Blouse  Clothing                     49
#
#         Location Size      Color  Season  Review Rating Subscription Status  \
# 0       Kentucky    L       Gray  Winter            3.1                 Yes
# 1          Maine    L     Maroon  Winter            3.1                 Yes
# 2  Massachusetts    S     Maroon  Spring            3.1                 Yes
# 3   Rhode Island    M     Maroon  Spring            3.5                 Yes
# 4         Oregon    M  Turquoise  Spring            2.7                 Yes
#
# ...

# %%
df.to_sql(
    "customer_behavior",
    engine,
    if_exists="replace",
    index=False
)

print("✅ Data imported successfully!")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python313\site-packages\sqlalchemy\engine\base.py:144, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     143 try:
# --> 144     self._dbapi_connection = engine.raw_connection()
#     145 except dialect.loaded_dbapi.Error as err:
#
# File ~\AppData\Roaming\Python\Python313\site-packages\sqlalchemy\engine\base.py:3319, in Engine.raw_connection(self)
#    3298 """Return a "raw" DBAPI connection from the connection pool.
#    3299
#    3300 The returned object is a proxied version of the DBAPI
#    (...)   3317
#    3318 """
# -> 3319 return self.pool.connect()
#
# File ~\AppData\Roaming\Python\Python313\site-packages\sqlalchemy\pool\base.py:448, in Pool.connect(self)
#     441 """Return a DBAPI connection from the pool.
#     442
# ...

# %%
from sqlalchemy import create_engine
from urllib.parse import quote_plus
import pandas as pd

password = quote_plus("Tanu123")   # try this

engine = create_engine(
    f"postgresql+psycopg://postgres:{password}@localhost:5432/customer_behavior"
)

conn = engine.connect()

print("Connected again")
# Out:
# Connected again

# %%
pd.read_sql("SELECT current_database(), current_user;", conn)
# Out:
#     current_database current_user
# 0  customer_behavior     postgres

# %%
pd.read_sql("""
SELECT table_name
FROM information_schema.tables
WHERE table_schema='public';
""", conn)
# Out:
#               table_name
# 0              customers
# 1      customer_behavior
# 2  customer_behavior_new

# %%
pd.read_sql("SELECT * FROM customer_behavior LIMIT 5;", conn)
# Out:
#    Customer ID  Age Gender Item Purchased  Category  Purchase Amount (USD)  \
# 0            1   55   Male         Blouse  Clothing                     53
# 1            2   19   Male        Sweater  Clothing                     64
# 2            3   50   Male          Jeans  Clothing                     73
# 3            4   21   Male        Sandals  Footwear                     90
# 4            5   45   Male         Blouse  Clothing                     49
#
#         Location Size      Color  Season  Review Rating Subscription Status  \
# 0       Kentucky    L       Gray  Winter            3.1                 Yes
# 1          Maine    L     Maroon  Winter            3.1                 Yes
# 2  Massachusetts    S     Maroon  Spring            3.1                 Yes
# 3   Rhode Island    M     Maroon  Spring            3.5                 Yes
# 4         Oregon    M  Turquoise  Spring            2.7                 Yes
#
# ...

# %%
df.columns = (
    df.columns
    .str.strip()
    .str.lower()
    .str.replace(" ", "_", regex=False)
)

df.to_sql(
    "customer_behavior_new",
    engine,
    if_exists="replace",
    index=False,
    chunksize=1000,
    method="multi"
)

print("Updated table saved successfully")
# Out:
# Updated table saved successfully

# %%
pd.read_sql("SELECT * FROM customer_behavior_new LIMIT 5;", engine)
# Out:
#    customer_id  age gender item_purchased  category  purchase_amount_(usd)  \
# 0            1   55   Male         Blouse  Clothing                     53
# 1            2   19   Male        Sweater  Clothing                     64
# 2            3   50   Male          Jeans  Clothing                     73
# 3            4   21   Male        Sandals  Footwear                     90
# 4            5   45   Male         Blouse  Clothing                     49
#
#         location size      color  season  review_rating subscription_status  \
# 0       Kentucky    L       Gray  Winter            3.1                 Yes
# 1          Maine    L     Maroon  Winter            3.1                 Yes
# 2  Massachusetts    S     Maroon  Spring            3.1                 Yes
# 3   Rhode Island    M     Maroon  Spring            3.5                 Yes
# 4         Oregon    M  Turquoise  Spring            2.7                 Yes
#
# ...

# %%
conn.close()

# %%
conn.close()
engine.dispose()

print("Jupyter database connections closed")
# Out:
# Jupyter database connections closed
